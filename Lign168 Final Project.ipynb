# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import os
import wave
import glob

# %%
from scipy.io import wavfile
from scipy import fft
from scipy import signal
from matplotlib import cm
import IPython.display as ipd
import matplotlib.pyplot as plt
from scipy.fft import fftshift
from scipy.spatial.distance import cdist
import librosa

# %%
#import neural models to help with detection 

from tensorflow import keras
from keras import layers
from keras import Input
from keras.layers import Conv1D, Conv2D, MaxPool1D, MaxPool2D, GlobalAvgPool1D, Dropout, BatchNormalization, Dense, LSTM, Flatten
# from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.regularizers import l2
from keras import backend as K

# %%
# Specify the folder containing the .wav files
folder_path = '/Users/kerichen/Downloads/Animals/bird'

# Use glob to find all .wav files in the folder
files = glob.glob(os.path.join(folder_path, '*.wav'))

# %%
librosa.load('/Users/kerichen/Downloads/Animals/bird/0a7c2a8d_nohash_0.wav')
# Out:
# (array([-0.00014037,  0.00117776, -0.00058977, ...,  0.00038463,
#          0.00082914,  0.00069896], dtype=float32),
#  22050)

# %%
#Define a function to help us get the features for each of the dataset

def get_features(files):
    X = []
    spectrograms = []
    mel_spectrograms = []
    mfccs = []

    for file in files:
        wav, sr = librosa.load(file, sr=None)

        spectrogram = np.abs(librosa.stft(wav))

        mel_spectrogram = librosa.feature.melspectrogram(y=wav, sr=sr)

        mfcc = librosa.feature.mfcc(y=wav, sr=sr)

        X.append(wav)
        spectrograms.append(spectrogram)
        mel_spectrograms.append(mel_spectrogram)
        mfccs.append(mfcc)
        
    # Pad sequences to ensure consistent shape for batch processing
    max_length = max(map(len, X))
    X = np.array([np.pad(x, (0, max_length - len(x)), 'constant') for x in X])

    # Ensure spectrogram, mel spectrogram, and MFCC have the same shape
    spectrograms = np.array([np.pad(s, ((0, 0), (0, max_length - s.shape[1])), 'constant') for s in spectrograms])
    mel_spectrograms = np.array([np.pad(m, ((0, 0), (0, max_length - m.shape[1])), 'constant') for m in mel_spectrograms])
    mfccs = np.array([np.pad(m, ((0, 0), (0, max_length - m.shape[1])), 'constant') for m in mfccs])
    
    return X, spectrograms, mel_spectrograms, mfccs

# %%
x_data_bird, spectrograms_bird, mel_spectrograms_bird, mfcss_bird = get_features(bird_files)

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(x_data_bird[0])), ref=np.max)


plt.figure(figsize = (10, 6))
librosa.display.specshow(D, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram');

# %%
# Specify the folder containing the .wav files
folder_path = '/Users/kerichen/Downloads/Animals/cat'

# Use glob to find all .wav files in the folder
cat_files = glob.glob(os.path.join(folder_path, '*.wav'))

# Iterate through the list of .wav files
#for cat_file in cat_files:
    # Open the .wav file
    #with wave.open(cat_file, 'rb') as wav_obj:
        # Extract and print some properties of the .wav file
       # print(f"Processing file: {wav_file}")
       # print(f"Number of channels: {wav_obj.getnchannels()}")
       # print(f"Sample width (bytes): {wav_obj.getsampwidth()}")
       # print(f"Frame rate (sample rate): {wav_obj.getframerate()}")
       # print(f"Number of frames: {wav_obj.getnframes()}")
       # print(f"Compression type: {wav_obj.getcomptype()}")
       # print(f"Compression name: {wav_obj.getcompname()}")
       # print("\n")

       #print (cat_file)

# %%
x_data_cat, spectrograms_cat, mel_spectrograms_cat, mfcss_cat = get_features(cat_files)

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(x_data_cat[0])), ref=np.max)


plt.figure(figsize = (10, 6))
librosa.display.specshow(D, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram');

# %%
# Specify the folder containing the .wav files
folder_path = '/Users/kerichen/Downloads/Animals/dog'

# Use glob to find all .wav files in the folder
dog_files = glob.glob(os.path.join(folder_path, '*.wav'))

# Iterate through the list of .wav files
#for dog_file in dog_files:
    # Open the .wav file
 #   with wave.open(dog_file, 'rb') as wav_obj:
        # Extract and print some properties of the .wav file
       # print(f"Processing file: {wav_file}")
       # print(f"Number of channels: {wav_obj.getnchannels()}")
       # print(f"Sample width (bytes): {wav_obj.getsampwidth()}")
       # print(f"Frame rate (sample rate): {wav_obj.getframerate()}")
       # print(f"Number of frames: {wav_obj.getnframes()}")
       # print(f"Compression type: {wav_obj.getcomptype()}")
       # print(f"Compression name: {wav_obj.getcompname()}")
       # print("\n")

      #  print (dog_file)

# %%
x_data_dog, spectrograms_dog, mel_spectrograms_dog, mfcss_dog = get_features(dog_files)

# %%
import os
import numpy as np
import librosa
import pandas as pd
from sklearn.model_selection import train_test_split

# Define the path to your dataset
data_path = '/Users/kerichen/Downloads/Animals/'

# Function to extract features from an audio file
def extract_features(file_path, n_fft=512):

    audio, sample_rate = librosa.load(file_path)

    
    # Ensure n_fft is appropriate for the length of the signal
    n_fft = min(n_fft, len(audio))
    
    # Compute various features
    mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40).T, axis=0)
    chroma = np.mean(librosa.feature.chroma_stft(y=audio, sr=sample_rate, n_fft=n_fft).T, axis=0)
    mel = np.mean(librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_fft=n_fft).T, axis=0)
    contrast = np.mean(librosa.feature.spectral_contrast(y=audio, sr=sample_rate, n_fft=n_fft).T, axis=0)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(audio), sr=sample_rate).T, axis=0)
    
    return np.hstack([mfccs, chroma, mel, contrast, tonnetz])


# Initialize lists to hold features and labels
features = []
labels = []

# Iterate over each class folder and extract features
for label in ['bird', 'cat', 'dog']:
    class_folder = os.path.join(data_path, label)
    for file_name in os.listdir(class_folder):
        file_path = os.path.join(class_folder, file_name)
        if file_name.endswith('.wav'):
            features.append(extract_features(file_path))
            labels.append(label)

# Convert lists to numpy arrays
X = np.array(features)
y = np.array(labels)

# %%
from sklearn.preprocessing import LabelEncoder

# Encode the labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Build the model
model = Sequential()
model.add(Dense(256, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes: bird, cat, dog

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 16/16 [==============================] - 0s 8ms/step - loss: 32.2614 - accuracy: 0.3074 - val_loss: 2.4202 - val_accuracy: 0.4098
# Epoch 2/50
# 16/16 [==============================] - 0s 3ms/step - loss: 17.0645 - accuracy: 0.3484 - val_loss: 1.7956 - val_accuracy: 0.4672
# Epoch 3/50
# 16/16 [==============================] - 0s 3ms/step - loss: 10.5730 - accuracy: 0.3607 - val_loss: 1.4316 - val_accuracy: 0.4016
# Epoch 4/50
# 16/16 [==============================] - 0s 3ms/step - loss: 7.6074 - accuracy: 0.3689 - val_loss: 1.5816 - val_accuracy: 0.3852
# Epoch 5/50
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9829 - accuracy: 0.3402 - val_loss: 1.1613 - val_accuracy: 0.3852
# Epoch 6/50
# 16/16 [==============================] - 0s 3ms/step - loss: 5.2817 - accuracy: 0.3053 - val_loss: 1.1444 - val_accuracy: 0.3607
# Epoch 7/50
# 16/16 [==============================] - 0s 3ms/step - loss: 4.0277 - accuracy: 0.3135 - val_loss: 1.1478 - val_accuracy: 0.3770
# Epoch 8/50
# 16/16 [==============================] - 0s 3ms/step - loss: 3.2544 - accuracy: 0.3668 - val_loss: 1.0828 - val_accuracy: 0.3443
# Epoch 9/50
# 16/16 [==============================] - 0s 3ms/step - loss: 3.1400 - accuracy: 0.2951 - val_loss: 1.0751 - val_accuracy: 0.3770
# Epoch 10/50
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1983 - accuracy: 0.4057 - val_loss: 1.0678 - val_accuracy: 0.4016
# Epoch 11/50
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1676 - accuracy: 0.3770 - val_loss: 1.0797 - val_accuracy: 0.4016
# Epoch 12/50
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1459 - accuracy: 0.3730 - val_loss: 1.0606 - val_accuracy: 0.3934
# Epoch 13/50
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1734 - accuracy: 0.3361 - val_loss: 1.0571 - val_accuracy: 0.4180
# Epoch 14/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.8379 - accuracy: 0.3709 - val_loss: 1.0751 - val_accuracy: 0.3443
# Epoch 15/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.9045 - accuracy: 0.3299 - val_loss: 1.0790 - val_accuracy: 0.3443
# Epoch 16/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5872 - accuracy: 0.3607 - val_loss: 1.0831 - val_accuracy: 0.3279
# Epoch 17/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5379 - accuracy: 0.3545 - val_loss: 1.0849 - val_accuracy: 0.4016
# Epoch 18/50
# 16/16 [==============================] - 0s 7ms/step - loss: 1.5134 - accuracy: 0.3463 - val_loss: 1.0898 - val_accuracy: 0.3770
# Epoch 19/50
# 16/16 [==============================] - 0s 4ms/step - loss: 1.4650 - accuracy: 0.3422 - val_loss: 1.0839 - val_accuracy: 0.4262
# Epoch 20/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.3455 - accuracy: 0.3607 - val_loss: 1.0826 - val_accuracy: 0.4344
# Epoch 21/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.3275 - accuracy: 0.3279 - val_loss: 1.0812 - val_accuracy: 0.3934
# Epoch 22/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2872 - accuracy: 0.3586 - val_loss: 1.0817 - val_accuracy: 0.3934
# Epoch 23/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2592 - accuracy: 0.4119 - val_loss: 1.0831 - val_accuracy: 0.3852
# Epoch 24/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2095 - accuracy: 0.4016 - val_loss: 1.0813 - val_accuracy: 0.4262
# Epoch 25/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1864 - accuracy: 0.4057 - val_loss: 1.0776 - val_accuracy: 0.4180
# Epoch 26/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2009 - accuracy: 0.3750 - val_loss: 1.0805 - val_accuracy: 0.4508
# Epoch 27/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2251 - accuracy: 0.3873 - val_loss: 1.0816 - val_accuracy: 0.4098
# Epoch 28/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1309 - accuracy: 0.3955 - val_loss: 1.0792 - val_accuracy: 0.3607
# Epoch 29/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1727 - accuracy: 0.4037 - val_loss: 1.0784 - val_accuracy: 0.3525
# Epoch 30/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1597 - accuracy: 0.3975 - val_loss: 1.0769 - val_accuracy: 0.3770
# Epoch 31/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1488 - accuracy: 0.4324 - val_loss: 1.0758 - val_accuracy: 0.3689
# Epoch 32/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1440 - accuracy: 0.3975 - val_loss: 1.0774 - val_accuracy: 0.3525
# Epoch 33/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1386 - accuracy: 0.3832 - val_loss: 1.0795 - val_accuracy: 0.3361
# Epoch 34/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1661 - accuracy: 0.3770 - val_loss: 1.0806 - val_accuracy: 0.3525
# Epoch 35/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0993 - accuracy: 0.3832 - val_loss: 1.0806 - val_accuracy: 0.3361
# Epoch 36/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1500 - accuracy: 0.4160 - val_loss: 1.0795 - val_accuracy: 0.3443
# Epoch 37/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1164 - accuracy: 0.4221 - val_loss: 1.0757 - val_accuracy: 0.3279
# Epoch 38/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1053 - accuracy: 0.4303 - val_loss: 1.0725 - val_accuracy: 0.3607
# Epoch 39/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1111 - accuracy: 0.4160 - val_loss: 1.0717 - val_accuracy: 0.3607
# Epoch 40/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0806 - accuracy: 0.4201 - val_loss: 1.0693 - val_accuracy: 0.3689
# Epoch 41/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0989 - accuracy: 0.4488 - val_loss: 1.0653 - val_accuracy: 0.3770
# Epoch 42/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1371 - accuracy: 0.3955 - val_loss: 1.0716 - val_accuracy: 0.3607
# Epoch 43/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0851 - accuracy: 0.4139 - val_loss: 1.0657 - val_accuracy: 0.3770
# Epoch 44/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1054 - accuracy: 0.4078 - val_loss: 1.0616 - val_accuracy: 0.3934
# Epoch 45/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0823 - accuracy: 0.4160 - val_loss: 1.0650 - val_accuracy: 0.3689
# Epoch 46/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0764 - accuracy: 0.3648 - val_loss: 1.0629 - val_accuracy: 0.3852
# Epoch 47/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0690 - accuracy: 0.4303 - val_loss: 1.0590 - val_accuracy: 0.3934
# Epoch 48/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0720 - accuracy: 0.4590 - val_loss: 1.0480 - val_accuracy: 0.4016
# Epoch 49/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0588 - accuracy: 0.4426 - val_loss: 1.0579 - val_accuracy: 0.3852
# Epoch 50/50
# 16/16 [==============================] - 0s 3ms/step - loss: 1.0502 - accuracy: 0.4549 - val_loss: 1.0603 - val_accuracy: 0.3852

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)
print(f'Test accuracy: {test_accuracy}')
# Out:
# 4/4 - 0s - loss: 1.0603 - accuracy: 0.3852 - 27ms/epoch - 7ms/step
# Test accuracy: 0.3852458894252777

# %%
# Function to predict the class of a new audio file
def predict_audio_class(file_path):
    features = extract_features(file_path)
    features = features.reshape(1, -1)
    prediction = model.predict(features)
    predicted_class = label_encoder.inverse_transform([np.argmax(prediction)])
    return predicted_class[0]

# Example usage
new_file_path = '/Users/kerichen/Downloads/Animals/dog/31e686d2_nohash_2.wav'
predicted_class = predict_audio_class(new_file_path)
print(f'The predicted class for the audio file is: {predicted_class}')
# Out:
# /Users/kerichen/anaconda3/envs/LIGN168v2/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
# /Users/kerichen/anaconda3/envs/LIGN168v2/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
# 1/1 [==============================] - 0s 252ms/step
# The predicted class for the audio file is: dog

# %%
import os
import numpy as np
import librosa
import pandas as pd
from sklearn.model_selection import train_test_split

# Define the path to your dataset
data_path = '/Users/kerichen/Downloads/Animals/'

# Function to extract features from an audio file
def extract_features(file_path, n_fft=512):

    audio, sample_rate = librosa.load(file_path)

    
    # Ensure n_fft is appropriate for the length of the signal
    n_fft = min(n_fft, len(audio))
    
    # Compute various features
    mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40).T, axis=0)
    chroma = np.mean(librosa.feature.chroma_stft(y=audio, sr=sample_rate, n_fft=n_fft).T, axis=0)
    mel = np.mean(librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_fft=n_fft).T, axis=0)
    contrast = np.mean(librosa.feature.spectral_contrast(y=audio, sr=sample_rate, n_fft=n_fft).T, axis=0)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(audio), sr=sample_rate).T, axis=0)
    
    #return np.hstack([mfccs, chroma, mel, contrast, tonnetz])
    return mel


# Initialize lists to hold features and labels
features = []
labels = []

# Iterate over each class folder and extract features
for label in ['bird', 'cat', 'dog']:
    class_folder = os.path.join(data_path, label)
    for file_name in os.listdir(class_folder):
        file_path = os.path.join(class_folder, file_name)
        if file_name.endswith('.wav'):
            features.append(extract_features(file_path))
            labels.append(label)

# Convert lists to numpy arrays
X = np.array(features)
y = np.array(labels)
# Out:
# /Users/kerichen/anaconda3/envs/LIGN168v2/lib/python3.11/site-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# /Users/kerichen/anaconda3/envs/LIGN168v2/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=545
#   warnings.warn(
# /Users/kerichen/anaconda3/envs/LIGN168v2/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=273
#   warnings.warn(

# %%
from sklearn.preprocessing import LabelEncoder

# Encode the labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Split the dataset
x_train, x_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.25,
                                                                                    #stratify splitting to ensure same target % in training and test sets
                                                                                     stratify = y_encoded,
                                                                                     #set random state to reproduce the same train-test split output
                                                                                     random_state = 0)

# %%
x_train_cnn = np.expand_dims(x_train, -1)
x_test_cnn = np.expand_dims(x_test, -1)

# %%
# x_train_cnn[0]
x_train.shape
x_train_cnn.shape

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)


# Reshape input data for CNN
X_train_cnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Build the CNN model
model = Sequential()
model.add(Conv1D(128, 5, padding='same', input_shape=(X_train_cnn.shape[1], 1), activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.5))
model.add(Conv1D(64, 5, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.5))
model.add(Conv1D(32, 5, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))  # 4 classes: bird, cat, dog, other

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_cnn, y_train, epochs=50, batch_size=32, validation_data=(X_test_cnn, y_test))

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_cnn, y_test, verbose=2)
print(f'Test accuracy: {test_accuracy}')
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 22ms/step - loss: 1.3677 - accuracy: 0.3299 - val_loss: 1.2584 - val_accuracy: 0.5574
# Epoch 2/50
# 16/16 [==============================] - 0s 13ms/step - loss: 1.1837 - accuracy: 0.4098 - val_loss: 1.0829 - val_accuracy: 0.4918
# Epoch 3/50
# 16/16 [==============================] - 0s 13ms/step - loss: 1.0497 - accuracy: 0.4693 - val_loss: 1.0338 - val_accuracy: 0.5328
# Epoch 4/50
# 16/16 [==============================] - 0s 14ms/step - loss: 1.0607 - accuracy: 0.4775 - val_loss: 1.0088 - val_accuracy: 0.5656
# Epoch 5/50
# 16/16 [==============================] - 0s 14ms/step - loss: 1.0072 - accuracy: 0.4918 - val_loss: 0.9719 - val_accuracy: 0.5984
# Epoch 6/50
# 16/16 [==============================] - 0s 14ms/step - loss: 1.0006 - accuracy: 0.5102 - val_loss: 0.9833 - val_accuracy: 0.6148
# Epoch 7/50
# 16/16 [==============================] - 0s 14ms/step - loss: 0.9849 - accuracy: 0.5184 - val_loss: 0.9239 - val_accuracy: 0.6311
# Epoch 8/50
# 16/16 [==============================] - 0s 20ms/step - loss: 0.9350 - accuracy: 0.5717 - val_loss: 0.8755 - val_accuracy: 0.6557
# Epoch 9/50
# 16/16 [==============================] - 0s 18ms/step - loss: 0.8664 - accuracy: 0.6168 - val_loss: 0.8536 - val_accuracy: 0.7049
# Epoch 10/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.9227 - accuracy: 0.5697 - val_loss: 0.8273 - val_accuracy: 0.7705
# Epoch 11/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.8238 - accuracy: 0.6250 - val_loss: 0.7752 - val_accuracy: 0.7705
# Epoch 12/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.8172 - accuracy: 0.6742 - val_loss: 0.7415 - val_accuracy: 0.7623
# Epoch 13/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.8356 - accuracy: 0.6414 - val_loss: 0.6828 - val_accuracy: 0.7705
# Epoch 14/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.7710 - accuracy: 0.6639 - val_loss: 0.6674 - val_accuracy: 0.7541
# Epoch 15/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.7446 - accuracy: 0.6844 - val_loss: 0.6240 - val_accuracy: 0.8443
# Epoch 16/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.7613 - accuracy: 0.6885 - val_loss: 0.6421 - val_accuracy: 0.7541
# Epoch 17/50
# 16/16 [==============================] - 0s 21ms/step - loss: 0.6707 - accuracy: 0.7070 - val_loss: 0.5927 - val_accuracy: 0.7869
# Epoch 18/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6494 - accuracy: 0.7070 - val_loss: 0.5646 - val_accuracy: 0.7951
# Epoch 19/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6685 - accuracy: 0.7090 - val_loss: 0.5561 - val_accuracy: 0.7787
# Epoch 20/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6518 - accuracy: 0.7049 - val_loss: 0.5517 - val_accuracy: 0.8115
# Epoch 21/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6070 - accuracy: 0.7439 - val_loss: 0.5173 - val_accuracy: 0.8033
# Epoch 22/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6324 - accuracy: 0.7336 - val_loss: 0.4865 - val_accuracy: 0.8279
# Epoch 23/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6325 - accuracy: 0.7561 - val_loss: 0.5093 - val_accuracy: 0.8443
# Epoch 24/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.5534 - accuracy: 0.7766 - val_loss: 0.4721 - val_accuracy: 0.8361
# Epoch 25/50
# 16/16 [==============================] - 0s 19ms/step - loss: 0.5935 - accuracy: 0.7500 - val_loss: 0.4792 - val_accuracy: 0.8033
# Epoch 26/50
# 16/16 [==============================] - 0s 19ms/step - loss: 0.5276 - accuracy: 0.7705 - val_loss: 0.4422 - val_accuracy: 0.8361
# Epoch 27/50
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5364 - accuracy: 0.7807 - val_loss: 0.4203 - val_accuracy: 0.8361
# Epoch 28/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.5518 - accuracy: 0.7889 - val_loss: 0.4412 - val_accuracy: 0.8443
# Epoch 29/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5262 - accuracy: 0.7828 - val_loss: 0.4781 - val_accuracy: 0.7869
# Epoch 30/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5384 - accuracy: 0.7684 - val_loss: 0.4079 - val_accuracy: 0.8607
# Epoch 31/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4811 - accuracy: 0.8176 - val_loss: 0.4040 - val_accuracy: 0.8361
# Epoch 32/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5172 - accuracy: 0.7869 - val_loss: 0.4031 - val_accuracy: 0.8607
# Epoch 33/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.5319 - accuracy: 0.8012 - val_loss: 0.4131 - val_accuracy: 0.8525
# Epoch 34/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4633 - accuracy: 0.8012 - val_loss: 0.3900 - val_accuracy: 0.8607
# Epoch 35/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4947 - accuracy: 0.7930 - val_loss: 0.3637 - val_accuracy: 0.9016
# Epoch 36/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.4596 - accuracy: 0.8279 - val_loss: 0.3757 - val_accuracy: 0.8607
# Epoch 37/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.5009 - accuracy: 0.7807 - val_loss: 0.3906 - val_accuracy: 0.8443
# Epoch 38/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4661 - accuracy: 0.8238 - val_loss: 0.3505 - val_accuracy: 0.8689
# Epoch 39/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4611 - accuracy: 0.8197 - val_loss: 0.3806 - val_accuracy: 0.8525
# Epoch 40/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4744 - accuracy: 0.8135 - val_loss: 0.4101 - val_accuracy: 0.8197
# Epoch 41/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4785 - accuracy: 0.8094 - val_loss: 0.3747 - val_accuracy: 0.8607
# Epoch 42/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4547 - accuracy: 0.8422 - val_loss: 0.3525 - val_accuracy: 0.8607
# Epoch 43/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4390 - accuracy: 0.8074 - val_loss: 0.3647 - val_accuracy: 0.8607
# Epoch 44/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4596 - accuracy: 0.8217 - val_loss: 0.3795 - val_accuracy: 0.8443
# Epoch 45/50
# 16/16 [==============================] - 0s 19ms/step - loss: 0.4292 - accuracy: 0.8176 - val_loss: 0.3389 - val_accuracy: 0.8607
# Epoch 46/50
# 16/16 [==============================] - 0s 17ms/step - loss: 0.4165 - accuracy: 0.8320 - val_loss: 0.3290 - val_accuracy: 0.8607
# Epoch 47/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4339 - accuracy: 0.8279 - val_loss: 0.3359 - val_accuracy: 0.8770
# Epoch 48/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4338 - accuracy: 0.8299 - val_loss: 0.3446 - val_accuracy: 0.8607
# Epoch 49/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4056 - accuracy: 0.8402 - val_loss: 0.3253 - val_accuracy: 0.9344
# Epoch 50/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4131 - accuracy: 0.8320 - val_loss: 0.3788 - val_accuracy: 0.8197
# 4/4 - 0s - loss: 0.3788 - accuracy: 0.8197 - 31ms/epoch - 8ms/step
# Test accuracy: 0.8196721076965332

# %%
# Function to predict the class of a new audio file
def predict_audio_class(file_path):
    features = extract_features(file_path)
    features = features.reshape(1, -1)
    prediction = model.predict(features)
    predicted_class = label_encoder.inverse_transform([np.argmax(prediction)])
    return predicted_class[0]

# Example usage
new_file_path = '/Users/kerichen/Downloads/Animals/cat/f264e0df_nohash_0.wav'
predicted_class = predict_audio_class(new_file_path)
print(f'The predicted class for the audio file is: {predicted_class}')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# The predicted class for the audio file is: cat
# /Users/kerichen/anaconda3/envs/LIGN168v2/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
# /Users/kerichen/anaconda3/envs/LIGN168v2/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
